# %%
import pandas as pd
import nltk
from nltk.parse.corenlp import CoreNLPDependencyParser
import stanfordnlp

# %%
data_review = pd.read_csv('./data/Performance Review Analysis.csv')

# %%
data_review.head()
# Out:
#    Respondent ID  Collector ID              Start Date  \
# 0            NaN           NaN                     NaN
# 1   6.759808e+09   171202168.0  03/15/2018 12:56:08 PM
# 2   6.759515e+09   171202168.0  03/15/2018 11:21:50 AM
# 3   6.759493e+09   171202168.0  03/15/2018 11:11:48 AM
# 4   6.759063e+09   171202168.0  03/15/2018 08:58:16 AM
#
#                  End Date  IP Address  Email Address  First Name  Last Name  \
# 0                     NaN         NaN            NaN         NaN        NaN
# 1  03/15/2018 01:02:46 PM         NaN            NaN         NaN        NaN
# 2  03/15/2018 11:28:27 AM         NaN            NaN         NaN        NaN
# 3  03/15/2018 11:21:41 AM         NaN            NaN         NaN        NaN
# 4  03/15/2018 09:02:59 AM         NaN            NaN         NaN        NaN
#
#    Custom Data 1  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# ...

# %%
idx_list = [data_review.columns[i] for i in range(len(data_review.columns))]

# %%
idx_list[9:18]
# Out:
# ['Person 1: please comment on job performance during the last year.',
#  'Person\xa01: please comment on how this person has worked with others.',
#  'Person 1: please suggest areas of improvement and targets for the next year.',
#  'Person 2: please comment on job performance during the last year.',
#  'Person 2: please comment on how this person has worked with others.',
#  'Person 2: please suggest areas of improvement and targets for the next year.',
#  'Person 3: please comment on job performance during the last year.',
#  'Person 3: please comment on how this person has worked with others.',
#  'Person 3: please suggest areas of improvement and targets for the next year.']

# %%
lst = []
dataset = pd.DataFrame()
for i in range(9,18):
    dataset['review'] = data_review[idx_list[i]]
    lst += dataset['review'].to_list()

# %%
len(lst)
# Out:
# 333

# %%
import pickle
with open('./data/performanceReview.pkl', 'wb') as f:
    pickle.dump(lst, f)
